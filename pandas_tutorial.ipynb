# %%
import pandas as pd
df=pd.read_csv('/content/Used Car Dataset.csv')

df
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549        1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
df[1:3]
# Out:
#    Unnamed: 0                                           car_name  \
# 1           1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2           2                       2018 BMW X1 sDrive 20d xLine
#
#   registration_year insurance_validity fuel_type  seats  kms_driven  \
# 1            Jan-21      Comprehensive    Petrol      5       30615
# 2            Sep-18      Comprehensive    Diesel      5       24000
#
#     ownsership transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 1  First Owner    Automatic               2020          17.40       999.0
# 2  First Owner    Automatic               2018          20.68      1995.0
#
#    max_power(bhp)  torque(Nm)  price(in lakhs)
# 1           999.0      9863.0             8.99
# 2          1995.0       188.0            23.75

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'car_name', 'registration_year', 'insurance_validity',
#        'fuel_type', 'seats', 'kms_driven', 'ownsership', 'transmission',
#        'manufacturing_year', 'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)',
#        'torque(Nm)', 'price(in lakhs)'],
#       dtype='object')

# %%
x=df['transmission']
y=df['seats']
print(x,y)
# Out:
# 0       Automatic
# 1       Automatic
# 2       Automatic
# 3          Manual
# 4       Automatic
#           ...
# 1548    Automatic
# 1549         2022
# 1550       Manual
# 1551       Manual
# 1552       Manual
# Name: transmission, Length: 1553, dtype: object 0       5
# 1       5
# 2       5
# 3       5
# 4       5
#        ..
# 1548    5
# 1549    5
# 1550    5
# 1551    5
# 1552    5
# Name: seats, Length: 1553, dtype: int64

# %%
df[['seats','transmission']]
# Out:
#       seats transmission
# 0         5    Automatic
# 1         5    Automatic
# 2         5    Automatic
# 3         5       Manual
# 4         5    Automatic
# ...     ...          ...
# 1548      5    Automatic
# 1549      5         2022
# 1550      5       Manual
# 1551      5       Manual
# 1552      5       Manual
#
# [1553 rows x 2 columns]

# %%
df['seats'].describe()
# Out:
# count     1553.000000
# mean        91.480361
# std       2403.424060
# min          4.000000
# 25%          5.000000
# 50%          5.000000
# 75%          5.000000
# max      67000.000000
# Name: seats, dtype: float64

# %%
df[df['seats']>7]
# Out:
#       Unnamed: 0                                         car_name  \
# 406          406         2016 Toyota Innova Crysta 2.4 G MT 8 STR
# 798          798  2013 Mercedes-Benz E-Class E 200 CGI Avantgarde
# 818          818  2013 Mercedes-Benz E-Class E 200 CGI Avantgarde
# 1311        1311                       2016 Maruti Omni E MPI STD
#
#           registration_year insurance_validity fuel_type  seats  kms_driven  \
# 406                  Oct-16      Comprehensive    Diesel      8       91000
# 798   Third Party insurance             Petrol   5 Seats  67000        1796
# 818   Third Party insurance             Petrol   5 Seats  67000        1796
# 1311                 Mar-16      Comprehensive    Petrol      8       23022
#
#         ownsership         transmission manufacturing_year  mileage(kmpl)  \
# 406   Second Owner               Manual               2016          13.68
# 798           2013  Power Windows Front    Air Conditioner         285.00
# ...

# %%
df[df['kms_driven']>=200000]
# Out:
#       Unnamed: 0                                car_name registration_year  \
# 1094        1094    2020 Hyundai Venue SX Plus Turbo DCT            Mar-20
# 1131        1131  2020 Ford Ecosport 1.5 Diesel Titanium            Oct-20
# 1420        1420    2012 Toyota Innova 2.5 VX 7 STR BSIV            Jun-12
#
#      insurance_validity fuel_type  seats  kms_driven   ownsership  \
# 1094           Zero Dep    Petrol      5      790000  First Owner
# 1131      Comprehensive    Diesel      5      810000  First Owner
# 1420      Comprehensive    Diesel      7      260000  First Owner
#
#      transmission manufacturing_year  mileage(kmpl)  engine(cc)  \
# 1094    Automatic               2020          18.15       998.0
# 1131       Manual               2020          21.70      1498.0
# 1420       Manual               2012          12.80      2494.0
#
#       max_power(bhp)  torque(Nm)  price(in lakhs)
# 1094           998.0     11835.0             9.75
# ...

# %%
df.fillna(0)
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549        1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
df.fillna(method='ffill')
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549        1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
df.fillna(method='bfill')
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549        1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
df.fillna(method='ffill',limit=1)
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549        1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
df=pd.read_csv('/content/Used Car Dataset.csv')
df.shape
# Out:
# (1553, 15)

# %%
df.dropna()
df.shape
# Out:
# (1553, 15)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# car_name              0
# registration_year     0
# insurance_validity    0
# fuel_type             0
# seats                 0
# kms_driven            0
# ownsership            0
# transmission          0
# manufacturing_year    0
# mileage(kmpl)         3
# engine(cc)            3
# max_power(bhp)        3
# torque(Nm)            4
# price(in lakhs)       0
# dtype: int64

# %%
df['seats'].value_counts()
# Out:
# 5        1353
# 7         156
# 4          22
# 6          18
# 8           2
# 67000       2
# Name: seats, dtype: int64

# %%
df['fuel_type'].value_counts()
# Out:
# Petrol     1013
# Diesel      516
# CNG          22
# 5 Seats       2
# Name: fuel_type, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'car_name', 'registration_year', 'insurance_validity',
#        'fuel_type', 'seats', 'kms_driven', 'ownsership', 'transmission',
#        'manufacturing_year', 'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)',
#        'torque(Nm)', 'price(in lakhs)'],
#       dtype='object')

# %%
df['registration_year'].value_counts()
# Out:
# 2017      40
# Jul-18    38
# Aug-18    29
# Jul-17    29
# May-17    26
#           ..
# Jul-10     1
# May-12     1
# Feb-13     1
# Nov-11     1
# Apr-14     1
# Name: registration_year, Length: 178, dtype: int64

# %%
df.loc[df['fuel_type']=="CNG"]
# Out:
#       Unnamed: 0                                car_name registration_year  \
# 37            37        2022 Tata Tiago XZ Plus CNG BSVI            Aug-22
# 57            57        2022 Tata Tiago XZ Plus CNG BSVI            Aug-22
# 75            75             2018 Maruti Wagon R CNG LXI            Feb-18
# 95            95             2018 Maruti Wagon R CNG LXI            Feb-18
# 219          219             2013 Maruti Wagon R LXI CNG            Aug-13
# 239          239             2013 Maruti Wagon R LXI CNG            Aug-13
# 366          366        2015 Hyundai Grand i10 Magna CNG            Oct-15
# 386          386        2015 Hyundai Grand i10 Magna CNG            Oct-15
# 514          514        2013 Hyundai Santro Xing GLS CNG              2013
# 534          534        2013 Hyundai Santro Xing GLS CNG              2013
# 675          675              2022 Maruti Ertiga ZXI CNG            Aug-22
# ...

# %%
df.loc[df['seats']==5]
# Out:
#       Unnamed: 0                                           car_name  \
# 0              0                    2017 Mercedes-Benz S-Class S400
# 1              1  2020 Nissan Magnite Turbo CVT XV Premium Opt BSVI
# 2              2                       2018 BMW X1 sDrive 20d xLine
# 3              3                           2019 Kia Seltos GTX Plus
# 4              4                    2019 Skoda Superb LK 1.8 TSI AT
# ...          ...                                                ...
# 1548        1548           2020 Hyundai Creta SX Opt Diesel AT BSVI
# 1549        1549                 2022 Renault KWID 1.0 RXL Opt BSVI
# 1550        1550                           2017 Honda WR-V i-VTEC S
# 1551        1551           2018 Volkswagen Polo 1.0 MPI Comfortline
# 1552        1552                        2018 Maruti Swift Dzire VXI
#
#      registration_year     insurance_validity fuel_type  seats  kms_driven  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'car_name', 'registration_year', 'insurance_validity',
#        'fuel_type', 'seats', 'kms_driven', 'ownsership', 'transmission',
#        'manufacturing_year', 'mileage(kmpl)', 'engine(cc)', 'max_power(bhp)',
#        'torque(Nm)', 'price(in lakhs)'],
#       dtype='object')

# %%
df.pivot(index='registration_year',columns='')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-cf0cce670cba> in <cell line: 1>()
# ----> 1 df.pivot(index='registration_year',columns='seats')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    8565         from pandas.core.reshape.pivot import pivot
#    8566
# -> 8567         return pivot(self, index=index, columns=columns, values=values)
#    8568
#    8569     _shared_docs[
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1553 entries, 0 to 1552
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1553 non-null   int64
#  1   car_name            1553 non-null   object
#  2   registration_year   1553 non-null   object
#  3   insurance_validity  1553 non-null   object
#  4   fuel_type           1553 non-null   object
#  5   seats               1553 non-null   int64
#  6   kms_driven          1553 non-null   int64
#  7   ownsership          1553 non-null   object
#  8   transmission        1553 non-null   object
#  9   manufacturing_year  1553 non-null   object
#  10  mileage(kmpl)       1550 non-null   float64
#  11  engine(cc)          1550 non-null   float64
#  12  max_power(bhp)      1550 non-null   float64
#  13  torque(Nm)          1549 non-null   float64
#  14  price(in lakhs)     1553 non-null   float64
# ...

# %%
df['registration_year'].duplicated().sum()
# Out:
# 1375

# %%
df['engine(cc)'].value_counts()
# Out:
# 1197.0     260
# 1497.0      83
# 1199.0      66
# 998.0       64
# 1198.0      62
#           ...
# 831.0        1
# 4036.0       1
# 2454.0       1
# 885.0        1
# 11345.0      1
# Name: engine(cc), Length: 147, dtype: int64

# %%
df.pivot(index='registration_year', columns='engine(cc)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-95cf9e851995> in <cell line: 1>()
# ----> 1 df.pivot(index='registration_year', columns='engine(cc)')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in pivot(self, index, columns, values)
#    8565         from pandas.core.reshape.pivot import pivot
#    8566
# -> 8567         return pivot(self, index=index, columns=columns, values=values)
#    8568
#    8569     _shared_docs[
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...
